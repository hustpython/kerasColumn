# %%
import os

# %%
os.path.splitext('/home/ubuntu/DataSpace/shushu/zhuti2/19/01-52-09.jpg')
# Out:
# ('/home/ubuntu/DataSpace/shushu/zhuti2/19/01-52-09', '.jpg')

# %%
file_dir = '/home/ubuntu/DataSpace/shushu/zhuti2/19/01-52-09.jpg'

# %%
x = os.path.relpath(file_dir, start = subpath).split('/')[:-1]

# %%
'-'.join(x)
# Out:
# 'zhuti2-19'

# %%
os.path.basename(file_dir)
# Out:
# '1901-52-09.jpg'

# %%
subpath = '/home/ubuntu/DataSpace/shushu'

# %%
os.walk(subpath)
# Out:
# <generator object walk at 0x7f2c6039a620>

# %%
for x in sorted(os.walk(subpath, followlinks=False),
                      key=lambda tpl: tpl[0]):
    print(x)
# Out:
# ('/home/ubuntu/DataSpace/shushu', ['zhuti2', 'zhuti5'], [])
# ('/home/ubuntu/DataSpace/shushu/zhuti2', ['86', '771', '512', '344', '317', '589', '1004', '153', '865', '284', '1030', '861', '1016', '932', '348', '557', '696', '521', '58', '850', '978', '369', '236', '929', '280', '776', '808', '205', '633', '866', '83', '19', '418', '72', '131', '832', '959', '626', '285', '240', '1057', '645', '28', '752', '500', '273', '690', '973', '614'], [])
# ...
